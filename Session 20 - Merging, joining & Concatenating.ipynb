# %%
import pandas as pd
import numpy as np

# %%
courses = pd.read_csv("courses.csv")
students = pd.read_csv("students.csv")
nov = pd.read_csv("reg-month1.csv")
dec = pd.read_csv("reg-month2.csv")

delivery = pd.read_csv("deliveries.csv")
matches = pd.read_csv("matches.csv")

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
pd.concat([nov,dec])
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# ...

# %%
pd.concat([nov,dec]).shape
# Out:
# (53, 2)

# %%
pd.concat([nov,dec], ignore_index= True)
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
regs = pd.concat([nov,dec], ignore_index= True)

# %%
nov.append(dec)
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# ...

# %%
nov.append(dec, ignore_index = True)
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
pd.concat([nov,dec], keys = ['nov','dec'])
# Out:
#         student_id  course_id
# nov 0           23          1
#     1           15          5
#     2           18          6
#     3           23          4
#     4           16          9
#     5           18          1
#     6            1          1
#     7            7          8
#     8           22          3
#     9           15          1
#     10          19          4
#     11           1          6
#     12           7         10
#     13          11          7
#     14          13          3
#     15          24          4
#     16          21          1
#     17          16          5
#     18          23          3
#     19          17          7
#     20          23          6
#     21          25          1
#     22          19          2
#     23          25         10
#     24           3          3
# dec 0            3          5
#     1           16          7
#     2           12         10
#     3           12          1
#     4           14          9
# ...

# %%
multi = pd.concat([nov,dec], keys = ['nov','dec'])

# %%
multi.loc['nov']
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
multi.loc[('nov', 24)]
# Out:
# student_id    3
# course_id     3
# Name: (nov, 24), dtype: int64

# %%
pd.concat([nov,dec], axis=1)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %%
pd.concat([nov,dec], axis=1).shape
# Out:
# (28, 4)

# %%
# inner join
a = pd.merge(regs,students, on='student_id')

# %%
a.shape
# Out:
# (50, 4)

# %%
a[['student_id', 'course_id', 'name']].sort_values('student_id')
# Out:
#     student_id  course_id                name
# 18           1          9       Kailash Harjo
# 17           1         10       Kailash Harjo
# 16           1          6       Kailash Harjo
# 15           1          1       Kailash Harjo
# 49           2          5         Esha Butala
# 39           3          3      Parveen Bhalla
# 40           3          5      Parveen Bhalla
# 23           7          6        Tarun Thaker
# 22           7          2        Tarun Thaker
# 20           7         10        Tarun Thaker
# 19           7          8        Tarun Thaker
# 21           7          7        Tarun Thaker
# 31          11         10  David Mukhopadhyay
# 30          11          8  David Mukhopadhyay
# 29          11          7  David Mukhopadhyay
# 43          12          5          Radha Dutt
# 41          12         10          Radha Dutt
# 42          12          1          Radha Dutt
# 44          12          7          Radha Dutt
# ...

# %%
# left join

# %%
pd.merge(courses,regs, on='course_id', how ='left')
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        23.0
# 1           1            python   2499        18.0
# 2           1            python   2499         1.0
# 3           1            python   2499        15.0
# 4           1            python   2499        21.0
# 5           1            python   2499        25.0
# 6           1            python   2499        12.0
# 7           1            python   2499        14.0
# 8           1            python   2499        38.0
# 9           2               sql   3499        19.0
# 10          2               sql   3499         7.0
# 11          3     data analysis   4999        22.0
# 12          3     data analysis   4999        13.0
# 13          3     data analysis   4999        23.0
# 14          3     data analysis   4999         3.0
# 15          3     data analysis   4999        16.0
# 16          4  machine learning   9999        23.0
# ...

# %%
# right join

# %%
pd.merge(courses,regs, how ='right', on='course_id')
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499          23
# 1           5           tableau   2499          15
# 2           6          power bi   1899          18
# 3           4  machine learning   9999          23
# 4           9            plotly    699          16
# 5           1            python   2499          18
# 6           1            python   2499           1
# 7           8            pandas   1099           7
# 8           3     data analysis   4999          22
# 9           1            python   2499          15
# 10          4  machine learning   9999          19
# 11          6          power bi   1899           1
# 12         10           pyspark   2499           7
# 13          7          ms sxcel   1599          11
# 14          3     data analysis   4999          13
# 15          4  machine learning   9999          24
# 16          1            python   2499          21
# ...

# %%
# outer join

# %%
students.merge(regs, how = 'outer', on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo     23.0        1.0
# 1            1       Kailash Harjo     23.0        6.0
# 2            1       Kailash Harjo     23.0       10.0
# 3            1       Kailash Harjo     23.0        9.0
# 4            2         Esha Butala      1.0        5.0
# 5            3      Parveen Bhalla      3.0        3.0
# 6            3      Parveen Bhalla      3.0        5.0
# 7            4         Marlo Dugal     14.0        NaN
# 8            5         Kusum Bahri      6.0        NaN
# 9            6  Lakshmi Contractor     10.0        NaN
# 10           7        Tarun Thaker      9.0        8.0
# 11           7        Tarun Thaker      9.0       10.0
# 12           7        Tarun Thaker      9.0        7.0
# 13           7        Tarun Thaker      9.0        2.0
# 14           7        Tarun Thaker      9.0        6.0
# 15           8      Radheshyam Dey      5.0        NaN
# ...

# %%
# find total revenue generated by the company

# %%
pd.merge(courses,regs, on='course_id', how ='inner')
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499          23
# 1           1            python   2499          18
# 2           1            python   2499           1
# 3           1            python   2499          15
# 4           1            python   2499          21
# 5           1            python   2499          25
# 6           1            python   2499          12
# 7           1            python   2499          14
# 8           1            python   2499          38
# 9           2               sql   3499          19
# 10          2               sql   3499           7
# 11          3     data analysis   4999          22
# 12          3     data analysis   4999          13
# 13          3     data analysis   4999          23
# 14          3     data analysis   4999           3
# 15          3     data analysis   4999          16
# 16          4  machine learning   9999          23
# ...

# %%
pd.merge(courses,regs, on='course_id', how ='inner')['price'].sum()
# Out:
# 154247

# %%
# find month by month revenue

# %%
pd.concat([nov,dec], keys=['nov','dec']).reset_index()
# Out:
#    level_0  level_1  student_id  course_id
# 0      nov        0          23          1
# 1      nov        1          15          5
# 2      nov        2          18          6
# 3      nov        3          23          4
# 4      nov        4          16          9
# 5      nov        5          18          1
# 6      nov        6           1          1
# 7      nov        7           7          8
# 8      nov        8          22          3
# 9      nov        9          15          1
# 10     nov       10          19          4
# 11     nov       11           1          6
# 12     nov       12           7         10
# 13     nov       13          11          7
# 14     nov       14          13          3
# 15     nov       15          24          4
# 16     nov       16          21          1
# 17     nov       17          16          5
# 18     nov       18          23          3
# 19     nov       19          17          7
# 20     nov       20          23          6
# ...

# %%
temp = pd.concat([nov,dec], keys=['nov','dec']).reset_index()

# %%
pd.merge(temp,courses, how = 'inner', on ='course_id')
# Out:
#    level_0  level_1  student_id  course_id       course_name  price
# 0      nov        0          23          1            python   2499
# 1      nov        5          18          1            python   2499
# 2      nov        6           1          1            python   2499
# 3      nov        9          15          1            python   2499
# 4      nov       16          21          1            python   2499
# 5      nov       21          25          1            python   2499
# 6      dec        3          12          1            python   2499
# 7      dec       23          14          1            python   2499
# 8      dec       27          38          1            python   2499
# 9      nov        1          15          5           tableau   2499
# 10     nov       17          16          5           tableau   2499
# 11     dec        0           3          5           tableau   2499
# 12     dec       11          12          5           tableau   2499
# ...

# %%
pd.merge(temp,courses, how = 'inner', on ='course_id').groupby('level_0')['price'].sum()
# Out:
# level_0
# dec    65072
# nov    89175
# Name: price, dtype: int64

# %%
# print the registration table
# cols - name - course - price

# %%
regs.shape
# Out:
# (53, 2)

# %%
pd.merge(regs,courses, how = 'inner', on ='course_id').merge(students, on='student_id')[['name', 'course_name', 'price']]
# Out:
#                   name       course_name  price
# 0       Chhavi Lachman            python   2499
# 1       Chhavi Lachman           tableau   2499
# 2       Chhavi Lachman          power bi   1899
# 3       Chhavi Lachman  machine learning   9999
# 4       Chhavi Lachman            plotly    699
# 5       Chhavi Lachman     data analysis   4999
# 6      Fardeen Mahabir            python   2499
# 7      Fardeen Mahabir          power bi   1899
# 8      Fardeen Mahabir            pandas   1099
# 9        Kailash Harjo            python   2499
# 10       Kailash Harjo          power bi   1899
# 11       Kailash Harjo            plotly    699
# 12       Kailash Harjo           pyspark   2499
# 13           Preet Sha            python   2499
# 14           Preet Sha           tableau   2499
# 15          Seema Kota            python   2499
# 16     Shashank D’Alia            python   2499
# 17     Shashank D’Alia           pyspark   2499
# 18          Radha Dutt            python   2499
# ...

# %%
# plot bar chart for revenue/course

# %%
pd.merge(regs,courses,on = 'course_id').groupby('course_name')['price'].sum().reset_index()
# Out:
#         course_name  price
# 0     data analysis  24995
# 1  machine learning  39996
# 2          ms sxcel   7995
# 3            pandas   4396
# 4            plotly   3495
# 5          power bi  11394
# 6           pyspark  14994
# 7            python  22491
# 8               sql   6998
# 9           tableau  17493

# %%
pd.merge(regs,courses,on = 'course_id').groupby('course_name')['price'].sum().plot(kind='bar')

# %%
# find the students who enrolled in both the months

# %%
np.intersect1d(nov['student_id'], dec['student_id'])
# Out:
# array([ 1,  3,  7, 11, 16, 17, 18, 22, 23], dtype=int64)

# %%
common = np.intersect1d(nov['student_id'], dec['student_id'])

# %%
students[students['student_id'].isin(common)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
# find course that got no enrollment

# %%
np.setdiff1d(courses['course_id'], regs['course_id'])
# Out:
# array([11, 12], dtype=int64)

# %%
not_enrolled = np.setdiff1d(courses['course_id'], regs['course_id'])

# %%
courses[courses['course_id'].isin(not_enrolled)]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %%
# find students who did not enrol into any course

# %%
np.setdiff1d(students['student_id'], regs['student_id'])
# Out:
# array([ 4,  5,  6,  8,  9, 10, 20], dtype=int64)

# %%
not_registered = np.setdiff1d(students['student_id'], regs['student_id'])

# %%
students[students['student_id'].isin(not_registered)]
# Out:
#     student_id                name  partner
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 19          20       Hanuman Hegde       11

# %%
# how many students did not enroll in any course

students[students['student_id'].isin(not_registered)].shape[0]
# Out:
# 7

# %%
# how much percent of students did not enroll in any course

# %%
round((students[students['student_id'].isin(not_registered)].shape[0] / len(students)) * 100, 2)
# Out:
# 28.0

# %%
# self join
# print student name - partner name for all enrolled students

# %%
students.merge(students,left_on ='partner', right_on='student_id')
# Out:
#     student_id_x              name_x  partner_x  student_id_y  \
# 0              1       Kailash Harjo         23            23
# 1              2         Esha Butala          1             1
# 2              3      Parveen Bhalla          3             3
# 3              4         Marlo Dugal         14            14
# 4              5         Kusum Bahri          6             6
# 5              6  Lakshmi Contractor         10            10
# 6              7        Tarun Thaker          9             9
# 7              8      Radheshyam Dey          5             5
# 8              9   Nitika Chatterjee          4             4
# 9             10      Aayushman Sant          8             8
# 10            11  David Mukhopadhyay         20            20
# 11            12          Radha Dutt         19            19
# 12            13      Munni Varghese         24            24
# 13            14    Pranab Natarajan         22            22
# ...

# %%
students.merge(students,left_on ='partner', right_on='student_id')[['name_x','name_y']]
# Out:
#                 name_x              name_y
# 0        Kailash Harjo      Chhavi Lachman
# 1          Esha Butala       Kailash Harjo
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal    Pranab Natarajan
# 4          Kusum Bahri  Lakshmi Contractor
# 5   Lakshmi Contractor      Aayushman Sant
# 6         Tarun Thaker   Nitika Chatterjee
# 7       Radheshyam Dey         Kusum Bahri
# 8    Nitika Chatterjee         Marlo Dugal
# 9       Aayushman Sant      Radheshyam Dey
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese        Radhika Suri
# 13    Pranab Natarajan          Yash Sethi
# 14           Preet Sha        Elias Dodiya
# 15        Elias Dodiya     Shashank D’Alia
# 16        Yasmin Palan        Tarun Thaker
# 17     Fardeen Mahabir      Munni Varghese
# 18        Qabeel Raman          Radha Dutt
# 19       Hanuman Hegde  David Mukhopadhyay
# 20          Seema Kota           Preet Sha
# ...

# %%
# find top 3 students who did most number enrollments

# %%
students.merge(regs, on='student_id').groupby(['student_id','name'])['name'].count().sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23          Chhavi Lachman    6
# 7           Tarun Thaker      5
# 1           Kailash Harjo     4
# Name: name, dtype: int64

# %%
# find top 3 students who spent most amount of money on courses

# %%
students.merge(regs, on='student_id').merge(courses, on= 'course_id').groupby(['student_id', 'name'])['price'].sum().sort_values(ascending=False).reset_index().head(3)
# Out:
#    student_id              name  price
# 0          23    Chhavi Lachman  22594
# 1          14  Pranab Natarajan  15096
# 2          19      Qabeel Raman  13498

# %%
# find top 3 stadium with highest sixes/match ratio

# %%
delivery.head(1)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 0            0            0             0             0           0
#
#    total_runs  player_dismissed dismissal_kind fielder
# 0           0               NaN            NaN     NaN
#
# [1 rows x 21 columns]

# %%
matches.head(1)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
delivery.merge(matches, left_on='match_id', right_on='id').head(1)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  result  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# 0           0  Sunrisers Hyderabad           35               0
#
#    player_of_match                                      venue      umpire1  \
# 0     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
#
# [1 rows x 39 columns]

# %%
temp = delivery.merge(matches, left_on='match_id', right_on='id')

# %%
sixes = temp[temp['batsman_runs'] == 6]

# %%
sixes_venue = sixes.groupby('venue')['match_id'].count().sort_values(ascending = False)

# %%
sixes.groupby('venue')['match_id'].count().sort_values(ascending = False).reset_index().head(3)
# Out:
#                    venue  match_id
# 0  M Chinnaswamy Stadium       873
# 1       Wankhede Stadium       657
# 2       Feroz Shah Kotla       636

# %%
total_matches = matches['venue'].value_counts()

# %%
(sixes_venue/total_matches).sort_values(ascending=False).head(3)
# Out:
# Holkar Cricket Stadium     17.600000
# M Chinnaswamy Stadium      13.227273
# Sharjah Cricket Stadium    12.666667
# dtype: float64

# %%
# find orange cap holder of all the seasons

# %%
temp.head(1)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  result  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# 0           0  Sunrisers Hyderabad           35               0
#
#    player_of_match                                      venue      umpire1  \
# 0     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
#
# [1 rows x 39 columns]

# %%
temp.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index()
# Out:
#       season      batsman  batsman_runs
# 0       2016      V Kohli           973
# 1       2016    DA Warner           848
# 2       2013   MEK Hussey           733
# 3       2012     CH Gayle           733
# 4       2013     CH Gayle           720
# ...      ...          ...           ...
# 1526    2017     MM Patel             0
# 1527    2012  AC Blizzard             0
# 1528    2011     AB Dinda             0
# 1529    2017      AD Nath             0
# 1530    2008     L Balaji             0
#
# [1531 rows x 3 columns]

# %%
temp.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).groupby(['season']).nth(0)
# Out:
# season
# 2008    616
# 2009    572
# 2010    618
# 2011    608
# 2012    733
# 2013    733
# 2014    660
# 2015    562
# 2016    973
# 2017    641
# Name: batsman_runs, dtype: int64

# %%
temp.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().groupby('season').first()
# Out:
#              batsman  batsman_runs
# season
# 2008        SE Marsh           616
# 2009       ML Hayden           572
# 2010    SR Tendulkar           618
# 2011        CH Gayle           608
# 2012        CH Gayle           733
# 2013      MEK Hussey           733
# 2014      RV Uthappa           660
# 2015       DA Warner           562
# 2016         V Kohli           973
# 2017       DA Warner           641

# %%
temp.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().groupby('season').last()
# Out:
#                batsman  batsman_runs
# season
# 2008          L Balaji             0
# 2009        KP Appanna             0
# 2010        YA Abdulla             0
# 2011          AB Dinda             0
# 2012       AC Blizzard             0
# 2013    Sandeep Sharma             0
# 2014      BE Hendricks             0
# 2015        PJ Cummins             0
# 2016         UBT Chand             0
# 2017           AD Nath             0

# %%
temp.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates('season', keep='first').sort_values('season')
# Out:
#     season       batsman  batsman_runs
# 10    2008      SE Marsh           616
# 14    2009     ML Hayden           572
# 9     2010  SR Tendulkar           618
# 11    2011      CH Gayle           608
# 3     2012      CH Gayle           733
# 2     2013    MEK Hussey           733
# 6     2014    RV Uthappa           660
# 17    2015     DA Warner           562
# 0     2016       V Kohli           973
# 7     2017     DA Warner           641
